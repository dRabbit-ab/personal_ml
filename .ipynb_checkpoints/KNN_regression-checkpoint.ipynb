# %%
# importing libraries
import pandas as pd
import numpy as np

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# KD-tree
from scipy.spatial import KDTree

# %% [markdown]
# ### TO-DO:

# %% [markdown]
# * Реализация простого KNN
# * Реализация KD-tree

# %% [markdown]
# ### Generating data

# %%
X = np.linspace(1, 10, 500).reshape(-1, 1)
y = np.sin(X.flatten()) + 0.3 * X.flatten() + 0.8 * np.random.randn(X.flatten().shape[0])

# making some anomalies
y[np.random.randint(0, X.shape[0], 10)] += 4
y[np.random.randint(0, X.shape[0], 10)] -= 4

plt.figure(figsize=(15, 5))
sns.scatterplot(x=X.flatten(), y=y)
plt.show()

# %% [markdown]
# ### Model creating

# %%
class KNN_Regressor:
    def __init__(self, k):
        self.k = k
        self.X = None
        self.y = None
        
    def fit(self, X, y):
        self.X = KDTree(X)
        self.y = y
        
    def predict(self, X):
        pass
